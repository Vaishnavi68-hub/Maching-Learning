# %%
import numpy as np

# %%
# Linear regression

class LinearRegression:
    def __init__(self ,learning_rate=0.01 , n_iter = 1000):
        self.bias = None
        self.weights = None
        self.lr = learning_rate
        self.n_iter = n_iter

    def fit(self , X , y): # X_train , y_train
        m , n = X.shape #(number of samples (m), no of features(n) -> rows and columns)


        #Step 1 -- initailize the parameters
        self.bias = 0
        self.weights = np.zeros(n) # [ 0,0,0....]


        #Gradient descent

        for i in range(self.n_iter):
            #Step 2 - calcutlate y_pred
            y_pred = self.bias + np.dot(X, self.weights)



            #Step 3 - gradient calcuttion
            db = (1/m) * np.sum(y_pred - y)
            dw = (1/m) * np.dot(X.T ,(y_pred - y))



            #Step 4 - convergence theorem - upadate parameters
            self.bias = self.bias - self.lr * db
            self.weights = self.weights - self.lr * db
        




    def predict(self , X):
        y_pred = self.bias + np.dot(X, self.weights)
        return y_pred

# %%
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8,10])


model = LinearRegression()
model.fit(X,y)
y_pred = model.predict(X)

print(y_pred)
# Out:
# [3.  4.5 6.  7.5 9. ]

# %%
print(model.bias)
print(model.weights)
# Out:
# 1.4999999999999973
# [1.5]

# %%
# Linear regression With OLS


class LinearRegressionOLS:

    def __init__(self):
        self.bias = None
        self.weights = None



    def fit(self , X,y):

        m , n = X.shape 

        X_b = np.c_[np.ones((m ,1)),X]

        #normal equation

        # theta = np.dot(np.linalg.inv(X_b.T , X_b) , np.dot(X_b.T ,y))
        theta = np.linalg.inv(X_b.T @ X_b) @ X_b.T  @ y


        self.bias = theta[0]
        self.weights = theta[1:]

        


    def predict(self, X):

        y_pred = self.bias * np.dot(X,self.weights)
        return y_pred

# %%
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8,10])


model = LinearRegressionOLS()
model.fit(X,y)
y_pred = model.predict(X)

print(y_pred)


print(model.bias)
print(model.weights)
# Out:
# [1.06581410e-14 2.13162821e-14 3.19744231e-14 4.26325641e-14
#  5.32907052e-14]
# 5.329070518200751e-15
# [2.]
